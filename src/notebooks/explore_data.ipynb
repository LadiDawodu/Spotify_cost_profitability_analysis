# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
pd.set_option('display.max_columns', 200)


df = pd.read_csv('/Users/ladi./Developer/data_analyst/PERSONAL PROJECTS/SPOTIFY/Spotify Quarterly.csv')

# %%
df.describe()
# Out:
#        Total Revenue  Cost of Revenue  Gross Profit  Premium Revenue  \
# count      25.000000        25.000000     25.000000        25.000000
# mean     1949.200000      1448.320000    501.280000      1721.400000
# std       688.571468       511.590634    188.493484       599.337203
# min       902.000000       775.000000    105.000000       828.000000
# 25%      1449.000000      1010.000000    373.000000      1210.000000
# 50%      1855.000000      1381.000000    479.000000      1700.000000
# 75%      2501.000000      1833.000000    668.000000      2178.000000
# max      3166.000000      2365.000000    801.000000      2717.000000
#
#        Premium Cost Revenue  Premium Gross Profit  Ad Revenue  \
# count             25.000000             25.000000   25.000000
# mean            1247.040000            474.360000  215.760000
# std              409.621419            191.566977  107.578762
# min              686.000000            118.000000   74.000000
# 25%              894.000000            316.000000  130.000000
# 50%             1219.000000            481.000000  175.000000
# 75%             1545.000000            633.000000  282.000000
# max             1939.000000            778.000000  449.000000
#
#        Ad Cost of revenue  Ad gross Profit        MAUs  Premium MAUs  \
# count           25.000000        25.000000   25.000000     25.000000
# mean           201.680000        14.080000  294.720000    130.080000
# std            105.019332        15.739864  117.212599     49.435918
# min             87.000000       -16.000000  131.000000     52.000000
# 25%            115.000000         4.000000  191.000000     87.000000
# 50%            157.000000        18.000000  286.000000    130.000000
# 75%            286.000000        25.000000  381.000000    172.000000
# max            426.000000        42.000000  515.000000    210.000000
#
#          Ad MAUs  Premium ARPU  Sales and Marketing Cost  \
# count   25.00000     26.000000                 25.000000
# mean   172.52000      4.702308                243.840000
# std     71.70258      0.452560                 95.165505
# min     82.00000      4.120000                110.000000
# 25%    109.00000      4.385000                172.000000
# 50%    163.00000      4.640000                236.000000
# 75%    220.00000      4.882500                294.000000
# max    317.00000      6.000000                453.000000
#
#        Research and Development Cost  Genreal and Adminstraive Cost
# count                      25.000000                      25.000000
# mean                      203.000000                     102.360000
# std                       101.236522                      34.507101
# min                        80.000000                      42.000000
# 25%                       135.000000                      73.000000
# 50%                       173.000000                     102.000000
# 75%                       253.000000                     126.000000
# max                       435.000000                     171.000000

# %%
df.shape

df.head(20)

df.columns

df.dtypes

df.describe()

#Data Prep

df.head()
# Out:
#          Date  Total Revenue  Cost of Revenue  Gross Profit  Premium Revenue  \
# 0  31-03-2023         3042.0           2276.0         776.0           2713.0
# 1  31-12-2022         3166.0           2365.0         801.0           2717.0
# 2  30-09-2022         3036.0           2286.0         750.0           2651.0
# 3  30-06-2022         2864.0           2160.0         704.0           2504.0
# 4  31-03-2022         2661.0           1990.0         671.0           2379.0
#
#    Premium Cost Revenue  Premium Gross Profit  Ad Revenue  Ad Cost of revenue  \
# 0                1937.0                 776.0       329.0               339.0
# 1                1939.0                 778.0       449.0               426.0
# 2                1908.0                 743.0       385.0               378.0
# 3                1804.0                 700.0       360.0               356.0
# 4                1704.0                 675.0       282.0               286.0
#
#    Ad gross Profit   MAUs  Premium MAUs  Ad MAUs  Premium ARPU  \
# 0            -10.0  515.0         210.0    317.0          4.32
# 1             23.0  489.0         205.0    295.0          4.55
# 2              7.0  456.0         195.0    273.0          4.63
# 3              4.0  433.0         188.0    265.0          4.54
# 4             -4.0  422.0         182.0    252.0          4.38
#
#    Sales and Marketing Cost  Research and Development Cost  \
# 0                     347.0                          435.0
# 1                     453.0                          415.0
# 2                     432.0                          386.0
# 3                     391.0                          336.0
# 4                     296.0                          250.0
#
#    Genreal and Adminstraive Cost
# 0                          140.0
# 1                          164.0
# 2                          160.0
# 3                          171.0
# 4                          131.0

# %%
df.isna().sum()
# Out:
# Date                             0
# Total Revenue                    1
# Cost of Revenue                  1
# Gross Profit                     1
# Premium Revenue                  1
# Premium Cost Revenue             1
# Premium Gross Profit             1
# Ad Revenue                       1
# Ad Cost of revenue               1
# Ad gross Profit                  1
# MAUs                             1
# Premium MAUs                     1
# Ad MAUs                          1
# Premium ARPU                     0
# Sales and Marketing Cost         1
# Research and Development Cost    1
# Genreal and Adminstraive Cost    1
# dtype: int64

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# dtype: bool

# %%
df.loc[df.duplicated]
# Out:
# Empty DataFrame
# Columns: [Date, Total Revenue, Cost of Revenue, Gross Profit, Premium Revenue, Premium Cost Revenue, Premium Gross Profit, Ad Revenue, Ad Cost of revenue, Ad gross Profit, MAUs, Premium MAUs, Ad MAUs, Premium ARPU, Sales and Marketing Cost, Research and Development Cost, Genreal and Adminstraive Cost]
# Index: []

# %%
missing_values = df.isnull().sum()

# %%
df_cleaned = df.dropna()

# %%
df_cleaned.isna().sum()
# Out:
# Date                             0
# Total Revenue                    0
# Cost of Revenue                  0
# Gross Profit                     0
# Premium Revenue                  0
# Premium Cost Revenue             0
# Premium Gross Profit             0
# Ad Revenue                       0
# Ad Cost of revenue               0
# Ad gross Profit                  0
# MAUs                             0
# Premium MAUs                     0
# Ad MAUs                          0
# Premium ARPU                     0
# Sales and Marketing Cost         0
# Research and Development Cost    0
# Genreal and Adminstraive Cost    0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#           Date  Total Revenue  Cost of Revenue  Gross Profit  Premium Revenue  \
# 0   31-03-2023         3042.0           2276.0         776.0           2713.0
# 1   31-12-2022         3166.0           2365.0         801.0           2717.0
# 2   30-09-2022         3036.0           2286.0         750.0           2651.0
# 3   30-06-2022         2864.0           2160.0         704.0           2504.0
# 4   31-03-2022         2661.0           1990.0         671.0           2379.0
# 5   31-12-2021         2689.0           1977.0         712.0           2295.0
# 6   30-09-2021         2501.0           1833.0         668.0           2178.0
# 7   30-06-2021         2331.0           1668.0         663.0           2056.0
# 8   31-03-2021         2147.0           1599.0         548.0           1931.0
# 9   31-12-2020         2168.0           1593.0         575.0           1887.0
# 10  30-09-2020         1975.0           1486.0         489.0           1790.0
# 11  30-06-2020         1889.0           1410.0         479.0           1758.0
# 12  31-03-2020         1848.0           1376.0         472.0           1700.0
# 13  31-12-2019         1855.0           1381.0         474.0           1638.0
# 14  30-09-2019         1731.0           1290.0         441.0           1561.0
# 15  30-06-2019         1667.0           1233.0         434.0           1502.0
# 4           4.38                     296.0                          250.0
# 5           4.40                     340.0                          253.0
# 6           4.34                     280.0                          208.0
# 7           4.29                     279.0                          255.0
# 8           4.12                     236.0                          196.0
# 9           4.26                     294.0                          232.0
# 10          4.19                     256.0                          176.0
# 11          4.41                     248.0                          267.0
# 12          4.42                     231.0                          162.0
# 13          4.65                     276.0                          173.0
# 14          4.67                     178.0                          136.0
# 15          4.86                     200.0                          151.0
# 16          4.71                     172.0                          155.0
# 17          4.89                     163.0                          100.0
# 18          4.73                     146.0                          135.0
# 19          4.89                     173.0                          143.0
# 20          4.72                     138.0                          115.0
# 21          5.24                     173.0                          123.0
# 22          5.06                     138.0                           98.0
# 23          5.53                     146.0                           95.0
# 24          5.46                     110.0                           80.0
#
#     Genreal and Adminstraive Cost
# 0                           140.0
# 1                           164.0
# 2                           160.0
# 3                           171.0
# 4                           131.0
# 5                           126.0
# 6                           105.0
# 7                           117.0
# 8                           102.0
# 9                           118.0
# 10                           97.0
# 11                          131.0
# 12                           96.0
# 13                          102.0
# 14                           73.0
# 15                           86.0
# 16                           93.0
# 17                           42.0
# 18                           67.0
# 19                          103.0
# 20                           71.0
# 21                           73.0
# 22                           67.0
# 23                           70.0
# 24                           54.0

# %%
revenue_columns = ["Total Revenue", "Premium Revenue","Ad Revenue"]
cost_columns = ['Sales and Marketing Cost', 'Research and Development Cost', 'Genreal and Adminstraive Cost']

def rev_stats(): 
        print("Revenue Stats:")       
        for col in revenue_columns:
                print(df[col].describe())

rev_stats()


def cost_stats(): 
        print("Cost Stats:")       
        for cost in cost_columns:
                print(df[cost].describe())

cost_stats()
# Out:
# Revenue Stats:
# count      25.000000
# mean     1949.200000
# std       688.571468
# min       902.000000
# 25%      1449.000000
# 50%      1855.000000
# 75%      2501.000000
# max      3166.000000
# Name: Total Revenue, dtype: float64
# count      25.000000
# mean     1721.400000
# std       599.337203
# min       828.000000
# 25%      1210.000000
# 50%      1700.000000
# 75%      2178.000000
# max      2717.000000
# Name: Premium Revenue, dtype: float64
# count     25.000000
# mean     215.760000
# std      107.578762
# min       74.000000
# 25%      130.000000
# 50%      175.000000
# 75%      282.000000
# max      449.000000
# Name: Ad Revenue, dtype: float64
# Cost Stats:
# count     25.000000
# mean     243.840000
# std       95.165505
# min      110.000000
# 25%      172.000000
# 50%      236.000000
# 75%      294.000000
# max      453.000000
# Name: Sales and Marketing Cost, dtype: float64
# count     25.000000
# mean     203.000000
# std      101.236522
# min       80.000000
# 25%      135.000000
# 50%      173.000000
# 75%      253.000000
# max      435.000000
# Name: Research and Development Cost, dtype: float64
# count     25.000000
# mean     102.360000
# std       34.507101
# min       42.000000
# 25%       73.000000
# 50%      102.000000
# 75%      126.000000
# max      171.000000
# Name: Genreal and Adminstraive Cost, dtype: float64

# %%
def skew():
        for cols in revenue_columns + cost_columns:
                print(f"{cols}: Skewness - {df[cols].skew()}")
        
skew()
# Out:
# Total Revenue: Skewness - 0.2795169411298381
# Premium Revenue: Skewness - 0.20811938612772563
# Ad Revenue: Skewness - 0.6872488566257309
# Sales and Marketing Cost: Skewness - 0.6702904635136636
# Research and Development Cost: Skewness - 1.0209750396227737
# Genreal and Adminstraive Cost: Skewness - 0.3606654521101974

# %%
def rev_costs():
        df.plot(kind="scatter",
                x="Total Revenue",
                y="Sales and Marketing Cost",
                title= 'Total Revenue vs. Cost of Revenue')
        plt.show()
rev_costs()

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Year'] = df['Date'].dt.year
df['Year']
decades_map = {
        2017: '2010s',
    2018: '2010s',
    2019: '2010s',
    2020: '2020s',
    2021: '2020s',
    2022: '2020s',
    2023: '2020s'
}

df['decades'] = df['Year'].map(decades_map)
# Out:
# <ipython-input-17-9db1f056b073>:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Date'] = pd.to_datetime(df['Date'])

# %%
sns.reset_defaults()
# def ad_rev_ad_cost_rev():
        #df['Ad Revenue'] = df['Ad Revenue'].astype(int)
ad_rev_ad_cost_rev = sns.scatterplot(data=df,
                x='Ad Revenue',
                y='Ad Cost of revenue',
                hue="decades")
ad_rev_ad_cost_rev.set_title('Ad Revenue vs. Ad Cost of revenue')
plt.show()

# %%
def trend_rev_over_years():
           plt.figure(figsize=(10, 6))
           # Total Revenue
           sns.lineplot(data=df, x='Year', y='Total Revenue', label='Total Revenue')
           # Premium Revenue
           sns.lineplot(data=df, x='Year', y='Premium Revenue', label='Premium Revenue')
           # Ad Revenue
           sns.lineplot(data=df, x='Year', y='Ad Revenue', label='Ad Revenue')
           plt.title('Trend of Revenue Over Years')
           plt.xlabel('Year')
           plt.ylabel('Revenue')
           plt.legend()
           plt.show()
trend_rev_over_years()

# %%
cost_columns = [
        'Sales and Marketing Cost',
        'Research and Development Cost', 
        'Genreal and Adminstraive Cost'
        ]

df['Total Cost'] = df[cost_columns].sum(axis=1)

# %%
def cost_over_time():
        plt.figure(figsize=(10,6))
        ax = sns.lineplot(data=df, x='Year', 
                        y='Total Cost', label = 'Cost Over Time')
        ax.set_title('Cost Prof')
        plt.show()

cost_over_time()

# %%
df['ROI'] = (df['Total Revenue'] - df['Ad Cost of revenue']) / df['Ad Cost of revenue']
print(df[['Date', 'Total Revenue', 'Ad Cost of revenue', 'ROI']])


scaled_roi = df['ROI'] * 100
def advertising_roi():
           plt.figure(figsize=(10, 6))
           
           #plt.subplots(ylim=(min(df['ROI']), max(df['ROI'])))  # Adjust limits as needed
           
           # Total Revenue
           sns.lineplot(data=df, x='Year', y='Total Revenue', label='Total Revenue')
           # Premium Revenue
           sns.lineplot(data=df, x='Year', y='Ad Cost of revenue', label='Ad Cost of revenue')
           # Ad Revenue
           sns.lineplot(data=df, x='Year', y=scaled_roi, label='ROI', linewidth=2)
           plt.title('Advertising ROI')
           plt.xlabel('Year')
           plt.ylabel('Revenue')
           plt.legend()
           plt.show()
advertising_roi()
# Out:
#          Date  Total Revenue  Ad Cost of revenue        ROI
# 0  2023-03-31         3042.0               339.0   7.973451
# 1  2022-12-31         3166.0               426.0   6.431925
# 2  2022-09-30         3036.0               378.0   7.031746
# 3  2022-06-30         2864.0               356.0   7.044944
# 4  2022-03-31         2661.0               286.0   8.304196
# 5  2021-12-31         2689.0               352.0   6.639205
# 6  2021-09-30         2501.0               288.0   7.684028
# 7  2021-06-30         2331.0               245.0   8.514286
# 8  2021-03-31         2147.0               206.0   9.422330
# 9  2020-12-31         2168.0               251.0   7.637450
# 10 2020-09-30         1975.0               184.0   9.733696
# 11 2020-06-30         1889.0               147.0  11.850340
# 12 2020-03-31         1848.0               157.0  10.770701
# 13 2019-12-31         1855.0               192.0   8.661458
# 14 2019-09-30         1731.0               148.0  10.695946
# 15 2019-06-30         1667.0               144.0  10.576389
# 16 2019-03-31         1511.0               115.0  12.139130
# 17 2018-12-31         1495.0               147.0   9.170068
# 18 2018-09-30         1352.0               116.0  10.655172
# 19 2018-06-30         1273.0               103.0  11.359223
# 20 2018-03-31         1139.0                89.0  11.797753
# 21 2017-12-31         1449.0               106.0  12.669811
# 22 2017-09-30         1032.0                91.0  10.340659
# 23 2017-06-30         1007.0                89.0  10.314607
# 24 2017-03-31          902.0                87.0   9.367816

# %%
ad_corr = df['Total Revenue'].corr(df['Ad Cost of revenue'])

ad_mau_corr = df['Total Revenue'].corr(df['MAUs'])

# %%
def revenue_relationship():
        plt.figure(figsize=(10,6))
        ax = sns.scatterplot(data=df,  
        x='Total Revenue', y='Ad Cost of revenue', label = 'Ad Cost of revenue relationship')
        ax.set_title('Ad Cost of revenue + Total Revenue Relationship ')
        plt.show()

revenue_relationship()


def muas_relationship():
        plt.figure(figsize=(10,6))
        ax = sns.scatterplot(data=df,  
        x='Total Revenue', y='Ad Cost of revenue', label = 'Ad Cost of revenue relationship')
        ax.set_title('Ad Cost of revenue + Total Revenue Relationship ')
        plt.show()

muas_relationship()

# %%
def muas_relationship():
        plt.figure(figsize=(10,6))
        ax = sns.lineplot(data=df,  
        x='Total Revenue', y='Ad Cost of revenue', label = 'Ad Cost of revenue relationship')
        ax.set_title('Ad Cost of revenue + Total Revenue Relationship ')
        plt.show()

muas_relationship()

# %%
def muas_relationship():
        plt.figure(figsize=(10,6))
        ax = sns.scatterplot(data=df,  
        x='Total Revenue', y='MUAs', label = 'Ad Cost of revenue relationship')
        ax.set_title('Ad Cost of revenue + Total Revenue Relationship ')
        plt.show()

muas_relationship()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /Users/ladi./Developer/data_analyst/PERSONAL PROJECTS/SPOTIFY/src/data/explore_data.py:8
#       5         ax.set_title('Ad Cost of revenue + Total Revenue Relationship ')
#       6         plt.show()
# ----> 8 muas_relationship()
#
# File /Users/ladi./Developer/data_analyst/PERSONAL PROJECTS/SPOTIFY/src/data/explore_data.py:3
#       1 def muas_relationship():
#       2         plt.figure(figsize=(10,6))
# ----> 3         ax = sns.scatterplot(data=df,
#       4         x='Total Revenue', y='MUAs', label = 'Ad Cost of revenue relationship')
#       5         ax.set_title('Ad Cost of revenue + Total Revenue Relationship ')
#       6         plt.show()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/relational.py:615, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     606 def scatterplot(
#     607     data=None, *,
#     608     x=None, y=None, hue=None, size=None, style=None,
#    (...)
#     612     **kwargs
#     613 ):
# --> 615     p = _ScatterPlotter(
#     616         data=data,
#     617         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#     618         legend=legend
#     619     )
#     621     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     622     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/relational.py:396, in _ScatterPlotter.__init__(self, data, variables, legend)
#     387 def __init__(self, *, data=None, variables={}, legend=None):
#     388
#     389     # TODO this is messy, we want the mapping to be agnostic about
#     390     # the kind of plot to draw, but for the time being we need to set
#     391     # this information so the SizeMapping can use it
#     392     self._default_size_range = (
#     393         np.r_[.5, 2] * np.square(mpl.rcParams["lines.markersize"])
#     394     )
# --> 396     super().__init__(data=data, variables=variables)
#     398     self.legend = legend
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_core/data.py:58, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
#      57     data = handle_data_source(data)
# ---> 58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#      61     self.names = names
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_core/data.py:232, in PlotData._assign_variables(self, data, variables)
#     230     else:
#     231         err += "An entry with this name does not appear in `data`."
# --> 232     raise ValueError(err)
#     234 else:
#     235
#     236     # Otherwise, assume the value somehow represents data
#     237
#     238     # Ignore empty data structures
#     239     if isinstance(val, Sized) and len(val) == 0:
#
# ValueError: Could not interpret value `MUAs` for `y`. An entry with this name does not appear in `data`.

# %%
def revenue_relationship():
        plt.figure(figsize=(10,6))
        ax = sns.lineplot(data=df,  
        x='Total Revenue', y='Ad Cost of revenue', label = 'Ad Cost of revenue relationship')
        
        ax2 = sns.lineplot(data=df,  
        x='Total Revenue', y='MAUs', label = 'Ad MAUs')
        
        plt.title('Ad Cost of revenue & MAU corr')
        plt.xlabel('Total Revenue')
        plt.ylabel('Ad Cost of revenue & MAU ')
        plt.legend()
        plt.show()

revenue_relationship()

# %%
cost_columns = [
        'Sales and Marketing Cost',
        'Research and Development Cost', 
        'Genreal and Adminstraive Cost'
        ]

df['Total Cost'] = df[cost_columns].sum(axis=1)

# %%
def cost_over_time():
        plt.figure(figsize=(10,6))
        ax = sns.lineplot(data=df, x='Date', 
                        y='Total Cost', label = 'Cost Over Time')
        ax.set_title('Cost Prof')
        plt.show()

cost_over_time()

# %%
df['ROI'] = (df['Total Revenue'] - df['Ad Cost of revenue']) / df['Ad Cost of revenue']
print(df[['Date', 'Total Revenue', 'Ad Cost of revenue', 'ROI']])
# Out:
#          Date  Total Revenue  Ad Cost of revenue        ROI
# 0  2023-03-31         3042.0               339.0   7.973451
# 1  2022-12-31         3166.0               426.0   6.431925
# 2  2022-09-30         3036.0               378.0   7.031746
# 3  2022-06-30         2864.0               356.0   7.044944
# 4  2022-03-31         2661.0               286.0   8.304196
# 5  2021-12-31         2689.0               352.0   6.639205
# 6  2021-09-30         2501.0               288.0   7.684028
# 7  2021-06-30         2331.0               245.0   8.514286
# 8  2021-03-31         2147.0               206.0   9.422330
# 9  2020-12-31         2168.0               251.0   7.637450
# 10 2020-09-30         1975.0               184.0   9.733696
# 11 2020-06-30         1889.0               147.0  11.850340
# 12 2020-03-31         1848.0               157.0  10.770701
# 13 2019-12-31         1855.0               192.0   8.661458
# 14 2019-09-30         1731.0               148.0  10.695946
# 15 2019-06-30         1667.0               144.0  10.576389
# 16 2019-03-31         1511.0               115.0  12.139130
# 17 2018-12-31         1495.0               147.0   9.170068
# 18 2018-09-30         1352.0               116.0  10.655172
# 19 2018-06-30         1273.0               103.0  11.359223
# 20 2018-03-31         1139.0                89.0  11.797753
# 21 2017-12-31         1449.0               106.0  12.669811
# 22 2017-09-30         1032.0                91.0  10.340659
# 23 2017-06-30         1007.0                89.0  10.314607
# 24 2017-03-31          902.0                87.0   9.367816

# %%
ad_corr = df['Total Revenue'].corr(df['Ad Cost of revenue'])

ad_mau_corr = df['Total Revenue'].corr(df['MAUs'])

# %%
def muas_relationship():
        plt.figure(figsize=(10,6))
        ax = sns.scatterplot(data=df,  
        x='Total Revenue', y='MAUs', label = 'Ad Cost of revenue relationship')
        ax.set_title('Ad Cost of revenue + Total Revenue Relationship ')
        plt.show()

muas_relationship()

# %%
def revenue_relationship():
        plt.figure(figsize=(10,6))
        ax = sns.lineplot(data=df,  
        x='Total Revenue', y='Ad Cost of revenue', label = 'Ad Cost of revenue relationship')
        
        ax2 = sns.lineplot(data=df,  
        x='Total Revenue', y='MAUs', label = 'Ad MAUs')
        
        plt.title('Ad Cost of revenue & MAU corr')
        plt.xlabel('Total Revenue')
        plt.ylabel('Ad Cost of revenue & MAU ')
        plt.legend()
        plt.show()

revenue_relationship()

# %%
def growth_mau():
        df['Premium MAUs Growth'] = df['Premium MAUs'].pct_change() * 100
        df['Ad MAUs Growth'] = df ['Ad MAUs'].pct_change() * 100

        plt.figure(figsize=(10,6))
        sns.lineplot(data=df, y='Premium MAUs Growth', x='Date', 
                label='Premium MAUs Growth')
        sns.lineplot(data=df, y='Ad MAUs Growth', x='Date', label='Ad MAUs Growth')
        plt.xlabel('Year')
        plt.ylabel('Growth Rate %')
        plt.title('Growth rates of premium MAUs and ad MAUs over time')
        plt.show()
growth_mau()

# %%
def growth_mau():
        df['Premium MAUs Growth'] = df['Premium MAUs'].pct_change() * 100
        df['Ad MAUs Growth'] = df ['Ad MAUs'].pct_change() * 100

        plt.figure(figsize=(10,6))
        sns.lineplot(data=df, y='Date', x='Premium MAUs Growth', 
                label='Premium MAUs Growth')
        sns.lineplot(data=df, y='Date', x='Ad MAUs Growt', label='Ad MAUs Growth')
        plt.xlabel('Year')
        plt.ylabel('Growth Rate %')
        plt.title('Growth rates of premium MAUs and ad MAUs over time')
        plt.show()
growth_mau()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /Users/ladi./Developer/data_analyst/PERSONAL PROJECTS/SPOTIFY/src/data/explore_data.py:13
#      11         plt.title('Growth rates of premium MAUs and ad MAUs over time')
#      12         plt.show()
# ---> 13 growth_mau()
#
# File /Users/ladi./Developer/data_analyst/PERSONAL PROJECTS/SPOTIFY/src/data/explore_data.py:8
#       5 plt.figure(figsize=(10,6))
#       6 sns.lineplot(data=df, y='Date', x='Premium MAUs Growth',
#       7         label='Premium MAUs Growth')
# ----> 8 sns.lineplot(data=df, y='Date', x='Ad MAUs Growt', label='Ad MAUs Growth')
#       9 plt.xlabel('Year')
#      10 plt.ylabel('Growth Rate %')
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/relational.py:485, in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     471 def lineplot(
#     472     data=None, *,
#     473     x=None, y=None, hue=None, size=None, style=None, units=None, weights=None,
#    (...)
#     481
#     482     # Handle deprecation of ci parameter
#     483     errorbar = _deprecate_ci(errorbar, ci)
# --> 485     p = _LinePlotter(
#     486         data=data,
#     487         variables=dict(
#     488             x=x, y=y, hue=hue, size=size, style=style, units=units, weight=weights
#     489         ),
#     490         estimator=estimator, n_boot=n_boot, seed=seed, errorbar=errorbar,
#     491         sort=sort, orient=orient, err_style=err_style, err_kws=err_kws,
#     492         legend=legend,
#     493     )
#     495     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     496     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/relational.py:216, in _LinePlotter.__init__(self, data, variables, estimator, n_boot, seed, errorbar, sort, orient, err_style, err_kws, legend)
#     202 def __init__(
#     203     self, *,
#     204     data=None, variables={},
#    (...)
#     210     # the kind of plot to draw, but for the time being we need to set
#     211     # this information so the SizeMapping can use it
#     212     self._default_size_range = (
#     213         np.r_[.5, 2] * mpl.rcParams["lines.linewidth"]
#     214     )
# --> 216     super().__init__(data=data, variables=variables)
#     218     self.estimator = estimator
#     219     self.errorbar = errorbar
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_core/data.py:58, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
#      57     data = handle_data_source(data)
# ---> 58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#      61     self.names = names
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_core/data.py:232, in PlotData._assign_variables(self, data, variables)
#     230     else:
#     231         err += "An entry with this name does not appear in `data`."
# --> 232     raise ValueError(err)
#     234 else:
#     235
#     236     # Otherwise, assume the value somehow represents data
#     237
#     238     # Ignore empty data structures
#     239     if isinstance(val, Sized) and len(val) == 0:
#
# ValueError: Could not interpret value `Ad MAUs Growt` for `x`. An entry with this name does not appear in `data`.

# %%
def growth_mau():
        df['Premium MAUs Growth'] = df['Premium MAUs'].pct_change() * 100
        df['Ad MAUs Growth'] = df ['Ad MAUs'].pct_change() * 100

        plt.figure(figsize=(10,6))
        sns.histplot(data=df, y='Date', x='Premium MAUs Growth', 
                label='Premium MAUs Growth')
        sns.histplot(data=df, y='Date', x='Ad MAUs Growth', label='Ad MAUs Growth')
        plt.xlabel('Year')
        plt.ylabel('Growth Rate %')
        plt.title('Growth rates of premium MAUs and ad MAUs over time')
        plt.show()
growth_mau()

# %%
def growth_mau():
        df['Premium MAUs Growth'] = df['Premium MAUs'].pct_change() * 100
        df['Ad MAUs Growth'] = df ['Ad MAUs'].pct_change() * 100

        plt.figure(figsize=(10,6))
        sns.scatterplot(data=df, y='Date', x='Premium MAUs Growth', 
                label='Premium MAUs Growth')
        sns.scatterplot(data=df, y='Date', x='Ad MAUs Growth', label='Ad MAUs Growth')
        plt.xlabel('Year')
        plt.ylabel('Growth Rate %')
        plt.title('Growth rates of premium MAUs and ad MAUs over time')
        plt.show()
growth_mau()

# %%
def growth_mau():
        df['Premium MAUs Growth'] = df['Premium MAUs'].pct_change() * 100
        df['Ad MAUs Growth'] = df ['Ad MAUs'].pct_change() * 100

        plt.figure(figsize=(10,6))
        sns.scatterplot(data=df, y='Premium MAUs Growth', x='Date', 
                label='Premium MAUs Growth')
        sns.scatterplot(data=df, y='Ad MAUs Growth', x='Date', label='Ad MAUs Growth')
        plt.xlabel('Date')
        plt.ylabel('Growth Rate %')
        plt.title('Growth rates of premium MAUs and ad MAUs over time')
        plt.show()
growth_mau()

# %%
def growth_mau():
        df['Premium MAUs Growth'] = df['Premium MAUs'].pct_change() * 100
        df['Ad MAUs Growth'] = df ['Ad MAUs'].pct_change() * 100

        plt.figure(figsize=(10,6))
        sns.lineplot(data=df, y='Premium MAUs Growth', x='Date', 
                label='Premium MAUs Growth')
        sns.lineplot(data=df, y='Ad MAUs Growth', x='Date', label='Ad MAUs Growth')
        plt.xlabel('Date')
        plt.ylabel('Growth Rate %')
        plt.title('Growth rates of premium MAUs and ad MAUs over time')
        plt.show()
growth_mau()

# %%
def growth_mau():
       # df['Premium MAUs Growth'] = df['Premium MAUs'].pct_change() * 100
        #df['Ad MAUs Growth'] = df ['Ad MAUs'].pct_change() * 100

        plt.figure(figsize=(10,6))
        sns.lineplot(data=df, y='Premium MAUs', x='Date', 
                label='Premium MAUs')
        sns.lineplot(data=df, y='Ad MAUs Growth', x='Date', label='Ad MAUs Growth')
        plt.xlabel('Date')
        plt.ylabel('Growth Rate %')
        plt.title('Growth rates of premium MAUs and ad MAUs over time')
        plt.show()
growth_mau()

# %%
def growth_mau():
       # df['Premium MAUs Growth'] = df['Premium MAUs'].pct_change() * 100
        #df['Ad MAUs Growth'] = df ['Ad MAUs'].pct_change() * 100

        plt.figure(figsize=(10,6))
        sns.lineplot(data=df, y='Premium MAUs', x='Date', 
                label='Premium MAUs')
        sns.lineplot(data=df, y='Ad MAUs', x='Date', label='Ad MAUs Growth')
        plt.xlabel('Date')
        plt.ylabel('Growth Rate %')
        plt.title('Growth rates of premium MAUs and ad MAUs over time')
        plt.show()
growth_mau()

# %%
def growth_mau():
        df['Premium MAUs Growth'] = df['Premium MAUs'].pct_change()
        df['Ad MAUs Growth'] = df ['Ad MAUs'].pct_change()

        plt.figure(figsize=(10,6))
        sns.lineplot(data=df, y='Premium MAUs', x='Date', 
                label='Premium MAUs')
        sns.lineplot(data=df, y='Ad MAUs', x='Date', label='Ad MAUs Growth')
        plt.xlabel('Date')
        plt.ylabel('Growth Rate %')
        plt.title('Growth rates of premium MAUs and ad MAUs over time')
        plt.show()
growth_mau()

# %%
df.describe()
# Out:
#                       Date  Total Revenue  Cost of Revenue  Gross Profit  \
# count                   25      25.000000        25.000000     25.000000
# mean   2020-03-30 21:07:12    1949.200000      1448.320000    501.280000
# min    2017-03-31 00:00:00     902.000000       775.000000    105.000000
# 25%    2018-09-30 00:00:00    1449.000000      1010.000000    373.000000
# 50%    2020-03-31 00:00:00    1855.000000      1381.000000    479.000000
# 75%    2021-09-30 00:00:00    2501.000000      1833.000000    668.000000
# max    2023-03-31 00:00:00    3166.000000      2365.000000    801.000000
# std                    NaN     688.571468       511.590634    188.493484
#
#        Premium Revenue  Premium Cost Revenue  Premium Gross Profit  \
# count        25.000000             25.000000             25.000000
# mean       1721.400000           1247.040000            474.360000
# min         828.000000            686.000000            118.000000
# 25%        1210.000000            894.000000            316.000000
# 50%        1700.000000           1219.000000            481.000000
# 75%        2178.000000           1545.000000            633.000000
# max        2717.000000           1939.000000            778.000000
# std         599.337203            409.621419            191.566977
#
#        Ad Revenue  Ad Cost of revenue  Ad gross Profit        MAUs  \
# count   25.000000           25.000000        25.000000   25.000000
# mean   215.760000          201.680000        14.080000  294.720000
# min     74.000000           87.000000       -16.000000  131.000000
# 25%    130.000000          115.000000         4.000000  191.000000
# 50%    175.000000          157.000000        18.000000  286.000000
# 75%    282.000000          286.000000        25.000000  381.000000
# max    449.000000          426.000000        42.000000  515.000000
# std    107.578762          105.019332        15.739864  117.212599
#
#        Premium MAUs    Ad MAUs  Premium ARPU  Sales and Marketing Cost  \
# count     25.000000   25.00000     25.000000                 25.000000
# mean     130.080000  172.52000      4.650400                243.840000
# min       52.000000   82.00000      4.120000                110.000000
# 25%       87.000000  109.00000      4.380000                172.000000
# 50%      130.000000  163.00000      4.630000                236.000000
# 75%      172.000000  220.00000      4.860000                294.000000
# max      210.000000  317.00000      5.530000                453.000000
# std       49.435918   71.70258      0.374661                 95.165505
#
#        Research and Development Cost  Genreal and Adminstraive Cost  \
# count                      25.000000                      25.000000
# mean                      203.000000                     102.360000
# min                        80.000000                      42.000000
# 25%                       135.000000                      73.000000
# 50%                       173.000000                     102.000000
# 75%                       253.000000                     126.000000
# max                       435.000000                     171.000000
# std                       101.236522                      34.507101
#
#               Year   Total Cost        ROI  Premium MAUs Growth  \
# count    25.000000    25.000000  25.000000            24.000000
# mean   2019.640000   549.200000   9.471453            -0.056041
# min    2017.000000   244.000000   6.431925            -0.126761
# 25%    2018.000000   369.000000   7.973451            -0.071744
# 50%    2020.000000   529.000000   9.422330            -0.046065
# 20          4.72                     138.0                          115.0
# 21          5.24                     173.0                          123.0
# 22          5.06                     138.0                           98.0
# 23          5.53                     146.0                           95.0
# 24          5.46                     110.0                           80.0
#
#     Genreal and Adminstraive Cost  Year decades  Total Cost        ROI  \
# 0                           140.0  2023   2020s       922.0   7.973451
# 1                           164.0  2022   2020s      1032.0   6.431925
# 2                           160.0  2022   2020s       978.0   7.031746
# 3                           171.0  2022   2020s       898.0   7.044944
# 4                           131.0  2022   2020s       677.0   8.304196
# 5                           126.0  2021   2020s       719.0   6.639205
# 6                           105.0  2021   2020s       593.0   7.684028
# 7                           117.0  2021   2020s       651.0   8.514286
# 8                           102.0  2021   2020s       534.0   9.422330
# 9                           118.0  2020   2020s       644.0   7.637450
# 10                           97.0  2020   2020s       529.0   9.733696
# 11                          131.0  2020   2020s       646.0  11.850340
# 12                           96.0  2020   2020s       489.0  10.770701
# 13                          102.0  2019   2010s       551.0   8.661458
# 14                           73.0  2019   2010s       387.0  10.695946
# 15                           86.0  2019   2010s       437.0  10.576389
# 16                           93.0  2019   2010s       420.0  12.139130
# 17                           42.0  2018   2010s       305.0   9.170068
# 18                           67.0  2018   2010s       348.0  10.655172
# 19                          103.0  2018   2010s       419.0  11.359223
# 20                           71.0  2018   2010s       324.0  11.797753
# 21                           73.0  2017   2010s       369.0  12.669811
# 22                           67.0  2017   2010s       303.0  10.340659
# 23                           70.0  2017   2010s       311.0  10.314607
# 24                           54.0  2017   2010s       244.0   9.367816
#
#     Premium MAUs Growth  Ad MAUs Growth
# 0                   NaN             NaN
# 1             -0.023810       -0.069401
# 2             -0.048780       -0.074576
# 3             -0.035897       -0.029304
# 4             -0.031915       -0.049057
# 5             -0.010989       -0.063492
# 6             -0.044444       -0.067797
# 7             -0.040698       -0.045455
# 8             -0.042424       -0.009524
# 9             -0.018987       -0.043269
# 10            -0.070968       -0.070352
# 11            -0.041667       -0.081081
# 12            -0.057971       -0.041176
# 13            -0.046154       -0.061350
# 14            -0.088710       -0.078431
# 15            -0.044248       -0.085106
# 16            -0.074074       -0.046512
# 17            -0.040000       -0.056911
# 18            -0.093750       -0.060345
# 19            -0.045977       -0.073394
# 20            -0.096386       -0.019802
# 21            -0.053333       -0.060606
# 22            -0.126761       -0.021505
# 23            -0.048387       -0.087912
# 24            -0.118644       -0.012048

# %%
plt.figure(figsize=(10, 6))
plt.bar(['Premium', 'Ad'], [premium_arpu.mean(), ad_arpu.mean()])
plt.xlabel('User Type')
plt.ylabel('Average Revenue per User (ARPU)')
plt.title('Comparison of ARPU between Premium and Ad Users')
plt.show()

# %%
fig,(ax1, ax2) = plt.subplots(2,1, figsize=(10,8))

sns.lineplot(data=df, x='Date', y='Gross Profit', 
        label='Gross Profit', ax=ax1)
ax1.set_ylabel('Gross Profit')

sns.lineplot(data=df, x='Date', y='Gross Profit Margin', 
        label='Gross Profit', ax=ax2)
ax1.set_ylabel('Gross Profit Margin %')

fig.suptitle('Gross Profit and Margin over Time')
plt.show()
